# %% [markdown]
# ### 1. Installing dependencies

# %%
import pathlib
import numpy as np
import random
import matplotlib.pyplot as plt
import os
import pandas as pd
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Getting the data from directory

# %%
file_path = './Alzheimer_MRI_4_classes_dataset/'
data_dir = pathlib.Path(file_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['MildDemented' 'ModerateDemented' 'NonDemented' 'VeryMildDemented']

# %% [markdown]
# ### 3. Visualizing random images with labels from the data

# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 20))
for i in range(16):
    ax = plt.subplot(4, 4, i+1)
    random_class = random.randint(0, 3)
    folder_path = file_path + '/' + class_names[random_class]
    random_image_path = folder_path + '/' + (random.sample(os.listdir(folder_path), 1)[0])
    image = plt.imread(random_image_path)
    
    # Preprocess the image
    if len(image.shape) == 2:  # Grayscale
        plt.imshow(image, cmap='gray')
    elif image.shape[-1] == 4:  # RGBA
        image = image[:, :, :3]  # Remove alpha channel
        plt.imshow(image)
    else:
        plt.imshow(image)
    
    plt.axis('off')
    plt.title(class_names[random_class], fontsize=15, fontweight='bold')

# %% [markdown]
# ### 4. Preparing the dataset for building CNN

# %%
SEED = 1   
BATCH_SIZE = 32
IMG_SIZE = (128, 128)

X_train = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed = SEED,
    image_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    validation_split = 0.2,
    subset = 'training'
)

X_validation = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed = SEED,
    image_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    validation_split = 0.2,
    subset = 'validation'
)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.

# %% [markdown]
# ### 5. Building the model

# %%
INPUT_SHAPE = IMG_SIZE + (3,)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Rescaling(scale=1./255, input_shape=INPUT_SHAPE))
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.20))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(4, activation = 'softmax'))

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,121,380 (8.09 MB)
#  Trainable params: 2,121,380 (8.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 6. Fitting the model

# %%
history = model.fit(X_train, epochs = 50, validation_data=X_validation, verbose=1)
# Out:
# Epoch 1/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 27s 156ms/step - accuracy: 0.5249 - loss: 1.0027 - val_accuracy: 0.5734 - val_loss: 0.8722
# Epoch 2/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - accuracy: 0.6408 - loss: 0.7975 - val_accuracy: 0.7281 - val_loss: 0.6195
# Epoch 3/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.7830 - loss: 0.5392 - val_accuracy: 0.8211 - val_loss: 0.4415
# Epoch 4/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 15s 95ms/step - accuracy: 0.8634 - loss: 0.3387 - val_accuracy: 0.9062 - val_loss: 0.2791
# Epoch 5/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 15s 94ms/step - accuracy: 0.9136 - loss: 0.2157 - val_accuracy: 0.9164 - val_loss: 0.2274
# Epoch 6/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9545 - loss: 0.1305 - val_accuracy: 0.9453 - val_loss: 0.1491
# Epoch 7/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9618 - loss: 0.1002 - val_accuracy: 0.9438 - val_loss: 0.1606
# Epoch 8/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.9668 - loss: 0.0898 - val_accuracy: 0.9688 - val_loss: 0.1022
# Epoch 9/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - accuracy: 0.9785 - loss: 0.0565 - val_accuracy: 0.9727 - val_loss: 0.0685
# Epoch 10/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.9843 - loss: 0.0509 - val_accuracy: 0.9641 - val_loss: 0.1066
# Epoch 11/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 15s 95ms/step - accuracy: 0.9888 - loss: 0.0302 - val_accuracy: 0.9758 - val_loss: 0.0719
# Epoch 12/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 15s 94ms/step - accuracy: 0.9833 - loss: 0.0486 - val_accuracy: 0.9781 - val_loss: 0.0616
# Epoch 13/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9927 - loss: 0.0269 - val_accuracy: 0.9742 - val_loss: 0.0749
# Epoch 14/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - accuracy: 0.9880 - loss: 0.0380 - val_accuracy: 0.9852 - val_loss: 0.0435
# Epoch 15/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - accuracy: 0.9916 - loss: 0.0233 - val_accuracy: 0.8453 - val_loss: 0.4469
# Epoch 16/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9726 - loss: 0.0734 - val_accuracy: 0.9773 - val_loss: 0.0715
# Epoch 17/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.9909 - loss: 0.0272 - val_accuracy: 0.9805 - val_loss: 0.0634
# Epoch 18/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - accuracy: 0.9918 - loss: 0.0244 - val_accuracy: 0.9844 - val_loss: 0.0390
# Epoch 19/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - accuracy: 0.9919 - loss: 0.0200 - val_accuracy: 0.9766 - val_loss: 0.0795
# Epoch 20/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9886 - loss: 0.0319 - val_accuracy: 0.9711 - val_loss: 0.0803
# Epoch 21/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9934 - loss: 0.0184 - val_accuracy: 0.9766 - val_loss: 0.0749
# Epoch 22/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9904 - loss: 0.0252 - val_accuracy: 0.9703 - val_loss: 0.1169
# Epoch 23/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 99ms/step - accuracy: 0.9873 - loss: 0.0351 - val_accuracy: 0.9695 - val_loss: 0.1029
# Epoch 24/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 98ms/step - accuracy: 0.9820 - loss: 0.0573 - val_accuracy: 0.9828 - val_loss: 0.0622
# Epoch 25/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.9938 - loss: 0.0174 - val_accuracy: 0.9852 - val_loss: 0.0454
# Epoch 26/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9946 - loss: 0.0138 - val_accuracy: 0.9820 - val_loss: 0.0691
# Epoch 27/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - accuracy: 0.9946 - loss: 0.0167 - val_accuracy: 0.9875 - val_loss: 0.0425
# Epoch 28/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9917 - loss: 0.0214 - val_accuracy: 0.9820 - val_loss: 0.0623
# Epoch 29/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9976 - loss: 0.0091 - val_accuracy: 0.9867 - val_loss: 0.0521
# Epoch 30/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.9952 - loss: 0.0159 - val_accuracy: 0.9797 - val_loss: 0.0687
# Epoch 31/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.9962 - loss: 0.0108 - val_accuracy: 0.9844 - val_loss: 0.0631
# Epoch 32/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.9984 - loss: 0.0041 - val_accuracy: 0.9820 - val_loss: 0.0662
# Epoch 33/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9933 - loss: 0.0208 - val_accuracy: 0.9805 - val_loss: 0.0812
# Epoch 34/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - accuracy: 0.9903 - loss: 0.0252 - val_accuracy: 0.9797 - val_loss: 0.0628
# Epoch 35/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.9935 - loss: 0.0170 - val_accuracy: 0.9836 - val_loss: 0.0529
# Epoch 36/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 111ms/step - accuracy: 0.9940 - loss: 0.0202 - val_accuracy: 0.9625 - val_loss: 0.1133
# Epoch 37/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9968 - loss: 0.0076 - val_accuracy: 0.9898 - val_loss: 0.0515
# Epoch 38/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - accuracy: 0.9954 - loss: 0.0141 - val_accuracy: 0.9789 - val_loss: 0.0885
# Epoch 39/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9886 - loss: 0.0281 - val_accuracy: 0.9617 - val_loss: 0.1405
# Epoch 40/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9948 - loss: 0.0164 - val_accuracy: 0.9750 - val_loss: 0.1181
# Epoch 41/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 103ms/step - accuracy: 0.9947 - loss: 0.0141 - val_accuracy: 0.9758 - val_loss: 0.0777
# Epoch 42/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - accuracy: 0.9887 - loss: 0.0343 - val_accuracy: 0.9312 - val_loss: 0.3170
# Epoch 43/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9903 - loss: 0.0289 - val_accuracy: 0.9914 - val_loss: 0.0239
# Epoch 44/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9883 - val_loss: 0.0630
# Epoch 45/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9987 - loss: 0.0026 - val_accuracy: 0.9914 - val_loss: 0.0282
# Epoch 46/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9914 - val_loss: 0.0357
# Epoch 47/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 105ms/step - accuracy: 0.9965 - loss: 0.0121 - val_accuracy: 0.9891 - val_loss: 0.0444
# Epoch 48/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9921 - loss: 0.0195 - val_accuracy: 0.9883 - val_loss: 0.0341
# Epoch 49/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - accuracy: 0.9966 - loss: 0.0129 - val_accuracy: 0.9930 - val_loss: 0.0336
# Epoch 50/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step - accuracy: 0.9954 - loss: 0.0133 - val_accuracy: 0.9836 - val_loss: 0.0613

# %% [markdown]
# ### 7. Model evaluation

# %%
model_evaluate = model.evaluate(X_validation)
print("Accuracy: %", "{:.2f}".format(model_evaluate[1]*100))
print("Loss: %", "{:.2f}".format(model_evaluate[0]*100))
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9815 - loss: 0.0778
# Accuracy: % 98.36
# Loss: % 6.13

# %%
df = pd.DataFrame(history.history)
ax = df.plot(figsize=(10,5), lw=3, grid='on')
ax.set_title('History per Epoch', fontsize=18, fontweight='bold')
ax.set_xlabel('Epochs', fontsize=15, fontweight='bold')
ax.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 20))
for image, label in X_validation.take(1): 
    for i in range(16):
        ax = plt.subplot(4, 4, i+1)
        img = image[i].numpy().astype("uint8")
        img = tf.expand_dims(img, axis=0)
        predicted_class = np.argmax(model.predict(img))
        plt.axis('off')
        plt.title("True Label: " + class_names[label[i]]+'\n', fontsize=12, style='italic', color='blue', loc='center')
        plt.title("Predicted Label: " + class_names[predicted_class], fontsize=12, fontweight='bold', color='green', loc='right')
        plt.imshow(image[i].numpy().astype("uint8"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
model.save('CNN.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Get true labels and predicted labels
y_true = []
y_pred = []

for image_batch, label_batch in X_validation:  # Iterate over validation batches
    y_true.extend(label_batch.numpy())
    predictions = model.predict(image_batch)
    y_pred.extend(np.argmax(predictions, axis=1))

# Step 2: Compute the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Step 3: Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix", fontsize=16, fontweight='bold')
plt.xlabel("Predicted Label", fontsize=14)
plt.ylabel("True Label", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12, rotation=0)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
